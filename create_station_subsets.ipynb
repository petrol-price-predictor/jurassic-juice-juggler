# %% [markdown]
# # Create subsets of stations
# Code that let's you create subset of stations.
#
# We use postcodes to filter stations according to our needs. All other address data related to the stations is varying much more in regards to data quality than the postcode - so the postcode is the best option to rely on.
#
# As reference we are using [a dataset from opendatasoft](https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/georef-germany-postleitzahl/exports/csv?lang=en&timezone=Europe%2FBerlin&use_labels=true&delimiter=%3B) here. It should be placed in the `data/` folder.
#
# From the generated `df_georef` we can use columns `state_name`, `kreis_name` and `location` (referring to the adminstrative level) to filter for the necessary postcodes.

# %%
import glob
import re
import pandas as pd
from tqdm import tqdm
from config import paths

# %%
# federal state name -> offical abbreviation
# useful later for bigger station subsets with more than one state
state_dict = {
    'Baden-Württemberg' :'BW',
    'Bayern': 'BY',
    'Berlin': 'BE',
    'Brandenburg': 'BB',
    'Bremen': 'HB',
    'Hamburg': 'HH',
    'Hessen': 'HE',
    'Mecklenburg-Vorpommern': 'MV',
    'Niedersachsen' : 'NI',
    'Nordrhein-Westfalen': 'NW',
    'Rheinland-Pfalz': 'RP',
    'Saarland': 'SL',
    'Sachsen': 'SN',
    'Sachsen-Anhalt': 'ST',
    'Schleswig-Holstein': 'SH',
    'Thüringen': 'TH'
}

# shortcut dict to select column from df_georef
administrative_level = {
   1: "state_name",
   2: "kreis_name",
   3: "location" 
}

# %%
# read the master postcode list and make it more accessible
df_georef = pd.read_csv("data/georef-germany-postleitzahl.csv", sep=';')
df_georef.rename(columns={'Name': 'name',
                    'PLZ Name (short)': 'location',
                    'PLZ Name (long)': 'plz_long',
                    'Geometry': 'geometry',
                    'Postleitzahl / Post code': 'plz',
                    'Kreis code': 'kreis_code',
                    'Land name': 'state_name',
                    'Land code': 'state_code',
                    'Kreis name': 'kreis_name'}, inplace=True)

# convert plz to string: to match to column 'post_code" in station list
# but there are (faulty) strings in the stations post_code column
df_georef = df_georef.astype({"plz": str})

df_georef.head(2)
# Out:
#     name     location           plz_long  \
# 0  47551  Bedburg-Hau  47551 Bedburg-Hau
# 1  52477      Alsdorf      52477 Alsdorf
#
#                                             geometry    plz  kreis_code  \
# 0  {"coordinates": [[[6.1156615, 51.7419192], [6....  47551        5154
# 1  {"coordinates": [[[6.1218109, 50.8594794], [6....  52477        5334
#
#             state_name  state_code                 kreis_name  \
# 0  Nordrhein-Westfalen           5                Kreis Kleve
# 1  Nordrhein-Westfalen           5  Kreis Städteregion Aachen
#
#                    geo_point_2d
# 0  51.7581345416, 6.20695861505
# 1    50.86861665, 6.17550818828

# %%
# work on sample station files for now
# create station list from files and deduplicate it
work_dir = paths.SAMPLE_DIR / "stations"
station_files = list(work_dir.glob("*.csv"))
station_list = pd.DataFrame()

for c in tqdm(range(0,len(station_files)), desc="Processing station files"):
# for filename in station_files:
    filename = station_files[0]
    current_file = pd.read_csv(filename)
    current_file["file_date"] = re.search("[\d]{4}-[\d]{2}-[\d]{2}",str(filename)).group()
    station_list = pd.concat([station_list, current_file])

station_list["file_date"] = pd.to_datetime(station_list["file_date"])
station_list.drop_duplicates(subset="uuid" ,inplace=True)
# Out:
# Processing station files: 100%|██████████| 13/13 [00:01<00:00,  9.91it/s]

# %%
def create_station_subset(names: list, level: int, filename_part: str) -> pd.DataFrame:
    '''
    Determines relevant postcodes of subset 
    Filters stations accordingly
    Saves subset as csv-file
    '''
    
    query_column = administrative_level[level]
    df_georefsubset = df_georef.query(f"{query_column} == @names")
    subset_postcodes = df_georefsubset["plz"].to_list()
    subset_stations = station_list[station_list["post_code"].isin(subset_postcodes)]
    subset_stations.to_csv(work_dir / f"stations_{filename_part}.csv", index=False)

    return subset_stations

# %%
# Subset 1: Düsseldorf and surrounding - using "location" (level 3)
dus_location_names = ["Düsseldorf", "Ratingen", "Erkrath", "Hilden", "Neuss", "Meerbusch"]
dus_subset = create_station_subset(dus_location_names, 3, 'dus_plus')

# %%
# Subset 2: Rheinland - going for "kreis_name" (level 2) here
rheinland_kreis_names = ['Kreis Borken',
                'Kreis Düren',
                'Kreis Euskirchen'
                'Kreis Heinsberg'
                'Kreis Kleve',
                'Kreis Mettmann'
                'Kreis Oberbergischer Kreis',
                'Kreis Rhein-Erft-Kreis',
                'Kreis Rhein-Kreis Neuss',
                'Kreis Rhein-Sieg-Kreis',
                'Kreis Rheinisch-Bergischer Kreis',
                'Kreis Städteregion Aachen',
                'Kreis Viersen',
                'Kreis Wesel',
                'Kreisfreie Stadt Bonn',
                'Kreisfreie Stadt Duisburg',
                'Kreisfreie Stadt Düsseldorf',
                'Kreisfreie Stadt Essen',
                'Kreisfreie Stadt Krefeld',
                'Kreisfreie Stadt Köln',
                'Kreisfreie Stadt Leverkusen',
                'Kreisfreie Stadt Mönchengladbach',
                'Kreisfreie Stadt Mülheim an der Ruhr',
                'Kreisfreie Stadt Oberhausen',
                'Kreisfreie Stadt Remscheid',
                'Kreisfreie Stadt Solingen',
                'Kreisfreie Stadt Wuppertal']

rheinland_subset = create_station_subset(rheinland_kreis_names, 2, 'rheinland')

# %%
# Subset 3: Nordrhein-Westfalen - simply go for "state_name" (level 1)
nrw_state_names = ['Nordrhein-Westfalen']
nrw_subset = create_station_subset(nrw_state_names, 1, 'nrw')

# %%
# just for checking
dus_subset.sort_values("city")
# Out:
#                                        uuid  \
# 3001   9f1a9948-4a60-4db6-8ac5-0fdffcf51613
# 9130   5e3c22de-18c6-4715-aa36-bc61244fd431
# 3869   c8608399-adf3-4162-8321-0f313ff043ac
# 9718   51d4b6fa-a095-1aa0-e100-80009459e03a
# 9804   51d4b683-a095-1aa0-e100-80009459e03a
# ...                                     ...
# 2954   b605dd15-57f6-495a-b1f9-645731f11272
# 3571   79fb1f24-bebb-489e-841f-728f9053b555
# 7529   9a9aabaf-adee-4180-87cb-e1a4c7fcd33e
# 1603   e7807347-796f-4aac-997d-07d0c988e109
# 16511  9c9d07ab-515a-54aa-0bac-df556a1f654b
#
#                                     name          brand  \
# 3001     DUESSELDORF, GRAFENBERGER ALLEE          Shell
# 9130                     Esso Tankstelle           ESSO
# 3869                   TOTAL DUESSELDORF          TOTAL
# 9718   JET DUESSELDORF RATHER BROICH 151            JET
# 9804   JET DUESSELDORF WORRINGER STR. 33            JET
# ...                                  ...            ...
# 2954        RATINGEN, BAT HÖSEL (OSTSEIT          Shell
# 3571              TotalEnergies Ratingen  TotalEnergies
# 7529                              Fricke      Tankpoint
# 1603     Shell Ratingen Brachter Str. 36          Shell
# 16511         Tramin Tankcenter Citytank            NaN
#
#                        street house_number post_code         city   latitude  \
# 3001   GRAFENBERGER ALLEE 230          NaN     40237  DUESSELDORF  51.234072
# 9130        ARNHEIMER STR. 22                  40489  DUESSELDORF  51.303623
# 3869          REISHOLZER STR.        57-63     40231  DUESSELDORF  51.206093
# 9718            RATHER BROICH          151     40472  DUESSELDORF  51.255400
# 9804           WORRINGER STR.           33     40211  DUESSELDORF  51.227690
# ...                       ...          ...       ...          ...        ...
# 2954                BAT HÖSEL          NaN     40883     Ratingen  51.325534
# 3571          Homberger Str.            21     40882     Ratingen  51.295966
# 7529             Stadionring            11     40878     Ratingen  51.298100
# 1603            Brachter Str.           36     40882     Ratingen  51.295287
# 16511       Hans-Böckler-Str.           24     40878     Ratingen  51.294533
#
#        longitude            first_active  \
# 3001    6.816542  2014-03-18 16:45:31+01
# 9130    6.740373  2014-03-18 16:45:31+01
# 3869    6.832643  2014-03-18 16:45:31+01
# 9718    6.821780  2014-03-18 16:45:31+01
# 9804    6.796300  2014-03-18 16:45:31+01
# ...          ...                     ...
# 2954    6.891643  2014-03-18 16:45:31+01
# 3571    6.866760  2014-03-18 16:45:31+01
# 7529    6.839630  2014-03-18 16:45:31+01
# 1603    6.914963  2014-03-18 16:45:31+01
# 16511   6.849886  2022-02-23 00:01:20+01
#
#                                        openingtimes_json  file_date
# 3001   {"overrides":[{"startp":"2019-07-01 12:00","en... 2023-05-01
# 9130   {"openingTimes":[{"applicable_days":63,"period... 2023-05-01
# 3869                                                  {} 2023-05-01
# 9718   {"openingTimes":[{"applicable_days":31,"period... 2023-05-01
# 9804   {"openingTimes":[{"applicable_days":31,"period... 2023-05-01
# ...                                                  ...        ...
# 2954   {"overrides":[{"startp":"2018-03-27 23:59","en... 2023-05-01
# 3571   {"openingTimes":[{"applicable_days":31,"period... 2023-05-01
# 7529   {"openingTimes":[{"applicable_days":64,"period... 2023-05-01
# 1603                                                  {} 2023-05-01
# 16511  {"openingTimes":[{"applicable_days":31,"period... 2023-05-01
#
# [130 rows x 12 columns]

# %% [markdown]
# ---
#
# ## Debugging & Testing Area
#
# ---

# %%
pd.set_option('display.max_rows', None)

# %%
dus_stations = pd.read_csv("data/sample/stations/stations_dus_plus.csv")
dus_stations.sort_values("brand").head(3)
# Out:
#      Unnamed: 0                                  uuid
# 127       15972  da6f245b-5aa2-419c-b00e-5daf159bdfc1  \
# 83         9481  529b7b56-0ff8-4f37-b116-d3b0144bf207
# 82         9103  39add580-4053-4eb2-8a4a-2744c249c48c
#
#                                      name brand               street
# 127  Aral Tankstelle, Ratingen Hohenstein  ARAL     Broichhofstrasse  \
# 83                        Aral Tankstelle  ARAL    Nürnberger Straße
# 82                        Aral Tankstelle  ARAL  Nievenheimer Straße
#
#     house_number  post_code        city   latitude  longitude
# 127       8(A52)      40880    Ratingen  51.290546   6.804400  \
# 83            33      40599  Düsseldorf  51.170425   6.859408
# 82             6      41469       Neuss  51.157720   6.731179
#
#                first_active
# 127  2020-04-23 06:01:16+02  \
# 83   2014-03-18 16:45:31+01
# 82   2014-03-18 16:45:31+01
#
#                                      openingtimes_json   file_date
# 127                                                 {}  2023-05-06
# 83   {"openingTimes":[{"applicable_days":31,"period...  2023-05-06
# 82   {"openingTimes":[{"applicable_days":31,"period...  2023-05-06

# %%
display(dus_stations.groupby(["brand"]).count().sort_values("uuid", ascending=False))
# Out:
#                          Unnamed: 0  uuid  name  street  house_number
# brand
# Shell                            26    26    26      26            22  \
# ARAL                             24    24    24      24            23
# ESSO                             21    21    21      21            21
# TotalEnergies                     9     9     9       9             9
# JET                               6     6     6       6             6
# STAR                              6     6     6       6             6
# SB                                5     5     5       5             4
# Freie Tankstelle                  3     3     3       3             3
# AVIA                              2     2     2       2             2
# Supermarkt-Tankstelle             2     2     2       2             1
# Sprint                            2     2     2       2             2
# SVG Düsseldorf                    2     2     2       2             2
# PM                                2     2     2       2             2
# OIL!                              2     2     2       2             0
# ELAN                              2     2     2       2             2
# Q1                                1     1     1       1             1
# ORLEN                             1     1     1       1             1
# Mr. Wash Autoservice AG           1     1     1       1             1
# Markant (Tankautomat)             1     1     1       1             1
# HEM                               1     1     1       1             1
# TOTAL                             1     1     1       1             1
# Tankpoint                         1     1     1       1             1
# CleanCar AG                       1     1     1       1             1
# Tramin City Tank                  1     1     1       1             1
#
#                          post_code  city  latitude  longitude  first_active
# brand
# Shell                           26    26        26         26            26  \
# ARAL                            24    24        24         24            24
# ESSO                            21    21        21         21            21
# TotalEnergies                    9     9         9          9             9
# JET                              6     6         6          6             6
# STAR                             6     6         6          6             6
# SB                               5     5         5          5             5
# Freie Tankstelle                 3     3         3          3             3
# AVIA                             2     2         2          2             2
# Supermarkt-Tankstelle            2     2         2          2             2
# Sprint                           2     2         2          2             2
# SVG Düsseldorf                   2     2         2          2             2
# PM                               2     2         2          2             2
# OIL!                             2     2         2          2             2
# ELAN                             2     2         2          2             2
# Q1                               1     1         1          1             1
# ORLEN                            1     1         1          1             1
# Mr. Wash Autoservice AG          1     1         1          1             1
# Markant (Tankautomat)            1     1         1          1             1
# HEM                              1     1         1          1             1
# TOTAL                            1     1         1          1             1
# Tankpoint                        1     1         1          1             1
# CleanCar AG                      1     1         1          1             1
# Tramin City Tank                 1     1         1          1             1
#
#                          openingtimes_json  file_date
# brand
# Shell                                   26         26
# ARAL                                    24         24
# ESSO                                    21         21
# TotalEnergies                            9          9
# JET                                      6          6
# STAR                                     6          6
# SB                                       5          5
# Freie Tankstelle                         3          3
# AVIA                                     2          2
# Supermarkt-Tankstelle                    2          2
# Sprint                                   2          2
# SVG Düsseldorf                           2          2
# PM                                       2          2
# OIL!                                     2          2
# ELAN                                     2          2
# Q1                                       1          1
# ORLEN                                    1          1
# Mr. Wash Autoservice AG                  1          1
# Markant (Tankautomat)                    1          1
# HEM                                      1          1
# TOTAL                                    1          1
# Tankpoint                                1          1
# CleanCar AG                              1          1
# Tramin City Tank                         1          1

# %% [markdown]
# ## Working with the processor classes

# %%
import src.process as pcs
help(pcs)
# Out:
# Help on module src.process in src:
#
# NAME
#     src.process
#
# FUNCTIONS
#     add_time_columns(df: pandas.core.frame.DataFrame, date='date', attributes=['year', 'month', 'day', 'dayofyear', 'dayofweek', 'hour', 'minute']) -> pandas.core.frame.DataFrame
#         Takes a Dataframe with a DateTime Index and creates columns for
#         ['year', 'month', 'day', 'dayofyear', 'dayofweek', 'hour', 'minute']
#
#         Args:
#             df (pd.DataFrame): DataFrame with DateTime ndex
#             date (str, optional): Name of the DateTime index. Defaults to 'date'.
#             attributes (list, optional): List if attributes from the DateTime library to create columns from. Defaults to ['year', 'month', 'day', 'dayofyear', 'dayofweek', 'hour', 'minute'].
#
#         Returns:
#             pd.DataFrame: DateTime Index DataFrame with new time columns
#
#     extend_panel(df: pandas.core.frame.DataFrame, date='date', individual='station_uuid', names=['date', 'station']) -> pandas.core.frame.DataFrame
#         Calls the methods to convert the DataFrame into a panel with a date and an individual column.
#         Then stratifies the DataFrame by extending all timestamps to all stations
#
#         Args:
#             df (pd.DataFrame): A DataFrame with at least one 'date' column and a second column representing individuals of a panel.
#             date (str, optional): Name of the date column. Defaults to 'date'.
#             individual (str, optional): Name of the individual column. Defaults to 'station_uuid'.
#             names (list, optional): Names for [date, individual] indices . Defaults to ['date','station'].
#
#         Returns:
#             pd.DataFrame: MultiIndex DataFrame with one time-series.
#
#     get_unique_index(df: pandas.core.frame.DataFrame, ind: Union[str, int]) -> pandas.core.series.Series
#         Returns a pd.Series of unique indices in the specified index.
#
#         Args:
#             df (pd.DataFrame): _description_
#             index (Union[str, int]): _description_
#
#         Returns:
#             pd.Series: _description_
#
#     get_unique_timestamps(df: pandas.core.frame.DataFrame, date='date') -> pandas.core.series.Series
#         Assuming a time-series DataFrame has their index set in Datetime format, returns a series with all unique timestamps
#
#         Args:
#             df (pd.DataFrame): A DataFrame in time-series format
#
#         Raises:
#             TypeError: The index must be a DatetimeIndex
#
#         Returns:
#             pd.Series: A pd.Series with unique timestamps of the original DataFrame in Datetime format, indexed with identical DatetimeIndex.
#
#     panel_index_from_product(df, dt_index, ind_index, names)
#         Helper Function for extend_panel to deal with exceptions
#
#     search_by_index(df: pandas.core.frame.DataFrame, index: Union[str, int], list_of_indices: List[str]) -> pandas.core.frame.DataFrame
#
#     set_datetime_index(ts_df: pandas.core.frame.DataFrame, date='date') -> pandas.core.frame.DataFrame
#         Takes a date-string column as argument, converts it to datetime format and sets it as the new index of the DataFrame.
#
#
#         Args:
#             ts_df (pd.DataFrame): A time-series DataFrame that isn't already in time-series format
#             date (str, optional): Name of the column with dates in string format. Defaults to 'date'.
#
#         Returns:
#             pd.DataFrame: A sorted time-series DataFrame.
#
#     set_panel_index(ts_df: pandas.core.frame.DataFrame, date='date', individual='', names=[]) -> pandas.core.frame.DataFrame
#         Takes a date-string column and an individual-column as argument and convert the DataFrame in a multi-index panel DataFrame
#
#         Args:
#             ts_df (pd.DataFrame): A time-series DataFrame that isn't already in time-series format
#             date (str, optional): Name of the column with dates in string format. Defaults to 'date'.
#             individual (str, optional): Name of the column with the specified panel individuals. Must not be an empty string.
#             names (list, optional): List of names for the indices.
#
#         Raises:
#             ValueError: The individual must be specified.
#
#         Returns:
#             pd.DataFrame: A multi-index panel DataFrame sorted by the datetime column.
#
#     swap_sort_index(df: pandas.core.frame.DataFrame) -> pandas.core.frame.DataFrame
#         Swaps the indices of a 2-index MultiIndex DataFrame and sorts the DataFrame by the new level-1 index.
#
#         Args:
#             df (pd.DataFrame): A MultiIndex Dataframe
#
#         Returns:
#             pd.DataFrame: A MultiIndex Dataframe with swapped indices, sorted by the new level-1 index.
#
# DATA
#     List = typing.List
#         A generic version of list.
#
#     Union = typing.Union
#         Union type; Union[X, Y] means either X or Y.
#
#         To define a union, use e.g. Union[int, str].  Details:
#         - The arguments must be types and there must be at least one.
#         - None as an argument is a special case and is replaced by
#           type(None).
#         - Unions of unions are flattened, e.g.::
#
#             Union[Union[int, str], float] == Union[int, str, float]
#
#         - Unions of a single argument vanish, e.g.::
#
#             Union[int] == int  # The constructor actually returns int
#
#         - Redundant arguments are skipped, e.g.::
#
#             Union[int, str, int] == Union[int, str]
#
#         - When comparing unions, the argument order is ignored, e.g.::
#
#             Union[int, str] == Union[str, int]
#
#         - You cannot subclass or instantiate a union.
#         - You can use Optional[X] as a shorthand for Union[X, None].
#
# FILE
#     /Users/markus/neuefische/jurassic-juice-juggler/src/process.py
